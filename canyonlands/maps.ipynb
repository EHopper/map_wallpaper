# %%
import glob

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageEnhance

from osgeo import gdal
gdal.SetConfigOption('GDAL_PDF_LAYERS', 'Map_Frame')
# gdal.SetConfigOption('GDAL_PDF_LAYERS_OFF',
#                      "Map_Frame.Projection_and_Grids")

# %%
# Coordinates of upper left corner, add -0.125N, 0.125W to get lower right
map_corners = [
    (38.375, -110.125, 'UT_Cleopatras_Chair_20200206_TM_geo.pdf'),
    (38.375, -109.625, 'UT_Eightmile_Rock_20200206_TM_geo.pdf'),
    (38.25, -110.125, 'UT_Elaterite_Basin_20200206_TM_geo.pdf'),
    (38.25, -109.625, 'UT_Harts_Point_North_20200206_TM_geo.pdf'),
    (38.375, -109.75, 'UT_Lockhart_Basin_20200206_TM_geo.pdf'),
    (38.375, -109.875, 'UT_Monument_Basin_20200206_TM_geo.pdf'),
    (38.25, -109.75, 'UT_North_Six-shooter_Peak_20200206_TM_geo.pdf'),
    (38.25, -110.0, 'UT_Spanish_Bottom_20200206_TM_geo.pdf'),
    (38.25, -109.875, 'UT_The_Loop_20200206_TM_geo.pdf'),
    (38.375,-110.0, 'UT_Turks_Head_20200206_TM_geo.pdf'),
]

# %%
def get_corners_from_gdal_ds(gdal_ds):
    ulx, xres, _, lry, _, yres = gdal_ds.GetGeoTransform()
    uly = orig_pdf.RasterYSize * yres + lry
    lrx = orig_pdf.RasterXSize * xres + ulx
    return ulx, uly, lrx, lry

# Get approx aspect ratio - just pick random one from the middle
fn = map_corners[len(map_corners)//2][-1]
orig_pdf = gdal.Open(fn)
ulx, uly, lrx, lry = get_corners_from_gdal_ds(orig_pdf)
ASPECT_RATIO = (ulx - lrx) / (uly - lry)

def warp_pdf(map_info):
    uly, ulx, quadrangle = map_info
    orig_pdf = gdal.Open(quadrangle)
    target_size = 4096 # equidistant
    warped = gdal.Warp(
        'warped.tif', orig_pdf, 
        dstSRS='EPSG:4326', # WGS84 
        resampleAlg='cubic',
        width=target_size, height=target_size,
        # this takes min_x, min_y, max_x, max_y
        outputBounds=(ulx, uly - 0.125, ulx + 0.125, uly)
    );
    warped.FlushCache();
    return warped

def gdal_ds_to_image(gdal_ds):
    a1 = gdal_ds.GetRasterBand(1).ReadAsArray()
    a2 = gdal_ds.GetRasterBand(2).ReadAsArray()
    a3 = gdal_ds.GetRasterBand(3).ReadAsArray()

    arr = np.stack((a1, a2, a3), axis=2)
    return Image.fromarray(arr)

def correct_aspect_ratio(im):
    return im.resize(
        (int(im.width * ASPECT_RATIO), im.height), Image.Resampling.BICUBIC
    )

def make_name_readable(fn):
    return fn.split('_20')[0][3:]
    

def do_all_the_things(map_info):
    im = correct_aspect_ratio(gdal_ds_to_image(warp_pdf(map_info)))
    im.save(f'{make_name_readable(map_info[-1])}.tif')
    return im

# %%
def merge_files(map_corners, crop_pixels=(0, 0, 0, 0)):
    
    row_lats = list(set(m[0] for m in map_corners))
    row_lats.sort()
    column_lons = list(set(m[1] for m in map_corners))
    column_lons.sort()

    # n.b. all input files have been transformed to the same size
    for ir, row in enumerate(row_lats):
        print(row)
        maps = [m for m in map_corners if m[0] == row]
        print(', '.join(make_name_readable(m[-1]) for m in maps))

        for ic, col in enumerate(column_lons):
            m = [m for m in maps if m[1] == col][0][-1]
            if ic == 0:
                im = Image.open(f'{make_name_readable(m)}.tif')
                im = crop_image(im, crop_pixels)
                continue 
            im_new = Image.open(f'{make_name_readable(m)}.tif')
            im_new = crop_image(im_new, crop_pixels)
            im = merge_im_horizontally(im, im_new)
        
        if ir == 0:
            im_all = im
            continue
        im_all = merge_im_vertically(im_all, im)

    return im_all

def crop_image(im, n_pixels):
    box = (n_pixels[0], n_pixels[1], im.width - n_pixels[2], im.height - n_pixels[3])
    return im.crop(box)
            
def merge_im_horizontally(im1, im2):
    w = im1.width + im2.width 
    h = im1.height
    im = Image.new("RGB", (w, h))
    im.paste(im1)
    im.paste(im2, (im1.width, 0))
    return im

def merge_im_vertically(im1, im2):
    w = im1.width
    h = im1.height + im2.height 
    im = Image.new("RGB", (w, h))
    im.paste(im2)
    im.paste(im1, (0, im2.height))
    return im

def increase_contrast(im, contrast_scale=3):
    enhancer = ImageEnhance.Contrast(im)
    return enhancer.enhance(contrast_scale)

# %%
for m in map_corners:
    # if len(glob.g÷lob(f'{make_name_readable(m[-1])}.tif')) == 0: # skip files that have already been processed
    print(make_name_readable(m[-1]))
    im = do_all_the_things(m)
    # break


im = merge_files(map_corners, (2, 1, 1, 2))
im.save('test.tif')
im3 = increase_contrast(im, 1.5)
sc = 1.5
im2 = im3.resize((int(im.width / sc), int(im.height / sc)), Image.Resampling.BICUBIC)
im2.save('final_map.tif')
# Out:
# Cleopatras_Chair
# ERROR 1: Pos = 62570527, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570527, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570534, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570534, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570552, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570559, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570566, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570566, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570569, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570569, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570569, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570569, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570576, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570580, insufficient arguments for Marked Content
# ERROR 1: Pos = 62572463, insufficient arguments for Marked Content
# ERROR 1: Pos = 62572469, insufficient arguments for Marked Content
# ERROR 1: Pos = 62572504, insufficient arguments for Marked Content
# ERROR 1: Pos = 62572504, insufficient arguments for Marked Content
# ERROR 1: Pos = 62572506, insufficient arguments for Marked Content
# ERROR 1: Pos = 62580828, insufficient arguments for Marked Content
# ERROR 1: Pos = 62580833, insufficient arguments for Marked Content
# ERROR 1: Pos = 62590400, insufficient arguments for Marked Content
# ERROR 1: Pos = 62593141, insufficient arguments for Marked Content
# ERROR 1: Pos = 62593147, insufficient arguments for Marked Content
# ERROR 1: Pos = 62596042, insufficient arguments for Marked Content
# ERROR 1: Pos = 62597501, insufficient arguments for Marked Content
# ERROR 1: Pos = 64029723, insufficient arguments for Marked Content
# ERROR 1: Pos = 64029729, insufficient arguments for Marked Content
# ERROR 1: Pos = 64122355, insufficient arguments for Marked Content
# ERROR 1: Pos = 64122673, insufficient arguments for Marked Content
# ERROR 1: Pos = 64122677, insufficient arguments for Marked Content
# ERROR 1: Pos = 64129829, insufficient arguments for Marked Content
# ERROR 1: Pos = 64144895, insufficient arguments for Marked Content
# ERROR 1: Pos = 64144901, insufficient arguments for Marked Content
# ERROR 1: Pos = 64149897, insufficient arguments for Marked Content
# ERROR 1: Pos = 64398846, insufficient arguments for Marked Content
# ERROR 1: Pos = 64841627, insufficient arguments for Marked Content
# ERROR 1: Pos = 64841633, insufficient arguments for Marked Content
# ERROR 1: Pos = 64961231, insufficient arguments for Marked Content
# ERROR 1: Pos = 64961237, insufficient arguments for Marked Content
# ERROR 1: Pos = 64970305, insufficient arguments for Marked Content
# ERROR 1: Pos = 64981998, insufficient arguments for Marked Content
# ERROR 1: Pos = 64984860, insufficient arguments for Marked Content
# ERROR 1: Pos = 64986962, insufficient arguments for Marked Content
# ERROR 1: Pos = 65018172, insufficient arguments for Marked Content
# ERROR 1: Pos = 65018178, insufficient arguments for Marked Content
# ERROR 1: Pos = 65021662, insufficient arguments for Marked Content
# ERROR 1: Pos = 65028167, insufficient arguments for Marked Content
# ERROR 1: Pos = 65028286, insufficient arguments for Marked Content
# ERROR 1: Pos = 65029087, insufficient arguments for Marked Content
# ERROR 1: Pos = 65029093, insufficient arguments for Marked Content
# ERROR 1: Pos = 65042645, insufficient arguments for Marked Content
# ERROR 1: Pos = 65055220, insufficient arguments for Marked Content
# ERROR 1: Pos = 65055226, insufficient arguments for Marked Content
# ERROR 1: Pos = 65057987, insufficient arguments for Marked Content
# ERROR 1: Pos = 65058144, insufficient arguments for Marked Content
# ERROR 1: Pos = 65058148, insufficient arguments for Marked Content
# ERROR 1: Pos = 65058222, insufficient arguments for Marked Content
# ERROR 1: Pos = 65058721, insufficient arguments for Marked Content
# ERROR 1: Pos = 65058725, insufficient arguments for Marked Content
# ERROR 1: Pos = 65059022, insufficient arguments for Marked Content
# ERROR 1: Pos = 65059038, insufficient arguments for Marked Content
# ERROR 1: Pos = 65059258, insufficient arguments for Marked Content
# ERROR 1: Pos = 65059262, insufficient arguments for Marked Content
# ERROR 1: Pos = 65059449, insufficient arguments for Marked Content
# ERROR 1: Pos = 65059480, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570527, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570527, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570534, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570534, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570552, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570559, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570566, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570566, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570569, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570569, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570569, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570569, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570576, insufficient arguments for Marked Content
# ERROR 1: Pos = 62570580, insufficient arguments for Marked Content
# ERROR 1: Pos = 62572463, insufficient arguments for Marked Content
# ERROR 1: Pos = 62572469, insufficient arguments for Marked Content
# ERROR 1: Pos = 62572504, insufficient arguments for Marked Content
# ERROR 1: Pos = 62572504, insufficient arguments for Marked Content
# ERROR 1: Pos = 62572506, insufficient arguments for Marked Content
# ERROR 1: Pos = 62580828, insufficient arguments for Marked Content
# ERROR 1: Pos = 62580833, insufficient arguments for Marked Content
# ERROR 1: Pos = 62590400, insufficient arguments for Marked Content
# ERROR 1: Pos = 62593141, insufficient arguments for Marked Content
# ERROR 1: Pos = 62593147, insufficient arguments for Marked Content
# ERROR 1: Pos = 62596042, insufficient arguments for Marked Content
# ERROR 1: Pos = 62597501, insufficient arguments for Marked Content
# ERROR 1: Pos = 64029723, insufficient arguments for Marked Content
# ERROR 1: Pos = 64029729, insufficient arguments for Marked Content
# ERROR 1: Pos = 64122355, insufficient arguments for Marked Content
# ERROR 1: Pos = 64122673, insufficient arguments for Marked Content
# ERROR 1: Pos = 64122677, insufficient arguments for Marked Content
# ERROR 1: Pos = 64129829, insufficient arguments for Marked Content
# ERROR 1: Pos = 64144895, insufficient arguments for Marked Content
# ERROR 1: Pos = 64144901, insufficient arguments for Marked Content
# ERROR 1: Pos = 64149897, insufficient arguments for Marked Content
# ERROR 1: Pos = 64398846, insufficient arguments for Marked Content
# ERROR 1: Pos = 64841627, insufficient arguments for Marked Content
# ERROR 1: Pos = 64841633, insufficient arguments for Marked Content
# ERROR 1: Pos = 64961231, insufficient arguments for Marked Content
# ERROR 1: Pos = 64961237, insufficient arguments for Marked Content
# ERROR 1: Pos = 64970305, insufficient arguments for Marked Content
# ERROR 1: Pos = 64981998, insufficient arguments for Marked Content
# ERROR 1: Pos = 64984860, insufficient arguments for Marked Content
# ERROR 1: Pos = 64986962, insufficient arguments for Marked Content
# ERROR 1: Pos = 65018172, insufficient arguments for Marked Content
# ERROR 1: Pos = 65018178, insufficient arguments for Marked Content
# ERROR 1: Pos = 65021662, insufficient arguments for Marked Content
# ERROR 1: Pos = 65028167, insufficient arguments for Marked Content
# ERROR 1: Pos = 65028286, insufficient arguments for Marked Content
# ERROR 1: Pos = 65029087, insufficient arguments for Marked Content
# ERROR 1: Pos = 65029093, insufficient arguments for Marked Content
# ERROR 1: Pos = 65042645, insufficient arguments for Marked Content
# ERROR 1: Pos = 65055220, insufficient arguments for Marked Content
# ERROR 1: Pos = 65055226, insufficient arguments for Marked Content
# ERROR 1: Pos = 65057987, insufficient arguments for Marked Content
# ERROR 1: Pos = 65058144, insufficient arguments for Marked Content
# ERROR 1: Pos = 65058148, insufficient arguments for Marked Content
# ERROR 1: Pos = 65058222, insufficient arguments for Marked Content
# ERROR 1: Pos = 65058721, insufficient arguments for Marked Content
# ERROR 1: Pos = 65058725, insufficient arguments for Marked Content
# ERROR 1: Pos = 65059022, insufficient arguments for Marked Content
# ERROR 1: Pos = 65059038, insufficient arguments for Marked Content
# ERROR 1: Pos = 65059258, insufficient arguments for Marked Content
# ERROR 1: Pos = 65059262, insufficient arguments for Marked Content
# ERROR 1: Pos = 65059449, insufficient arguments for Marked Content
# ERROR 1: Pos = 65059480, insufficient arguments for Marked Content
# Eightmile_Rock
# ERROR 1: Pos = 43700946, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700952, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700954, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700954, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700975, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700982, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700992, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700996, insufficient arguments for Marked Content
# ERROR 1: Pos = 43702887, insufficient arguments for Marked Content
# ERROR 1: Pos = 43702892, insufficient arguments for Marked Content
# ERROR 1: Pos = 43702928, insufficient arguments for Marked Content
# ERROR 1: Pos = 43702928, insufficient arguments for Marked Content
# ERROR 1: Pos = 43702930, insufficient arguments for Marked Content
# ERROR 1: Pos = 43741956, insufficient arguments for Marked Content
# ERROR 1: Pos = 43741962, insufficient arguments for Marked Content
# ERROR 1: Pos = 43744459, insufficient arguments for Marked Content
# ERROR 1: Pos = 43757387, insufficient arguments for Marked Content
# ERROR 1: Pos = 43757392, insufficient arguments for Marked Content
# ERROR 1: Pos = 43761799, insufficient arguments for Marked Content
# ERROR 1: Pos = 43762689, insufficient arguments for Marked Content
# ERROR 1: Pos = 44466698, insufficient arguments for Marked Content
# ERROR 1: Pos = 44466703, insufficient arguments for Marked Content
# ERROR 1: Pos = 44512720, insufficient arguments for Marked Content
# ERROR 1: Pos = 44513015, insufficient arguments for Marked Content
# ERROR 1: Pos = 44513019, insufficient arguments for Marked Content
# ERROR 1: Pos = 44555203, insufficient arguments for Marked Content
# ERROR 1: Pos = 44555209, insufficient arguments for Marked Content
# ERROR 1: Pos = 44802320, insufficient arguments for Marked Content
# ERROR 1: Pos = 45296305, insufficient arguments for Marked Content
# ERROR 1: Pos = 45296310, insufficient arguments for Marked Content
# ERROR 1: Pos = 45355064, insufficient arguments for Marked Content
# ERROR 1: Pos = 45355070, insufficient arguments for Marked Content
# ERROR 1: Pos = 45365882, insufficient arguments for Marked Content
# ERROR 1: Pos = 45370554, insufficient arguments for Marked Content
# ERROR 1: Pos = 45374725, insufficient arguments for Marked Content
# ERROR 1: Pos = 45385071, insufficient arguments for Marked Content
# ERROR 1: Pos = 45385076, insufficient arguments for Marked Content
# ERROR 1: Pos = 45388502, insufficient arguments for Marked Content
# ERROR 1: Pos = 45395284, insufficient arguments for Marked Content
# ERROR 1: Pos = 45395393, insufficient arguments for Marked Content
# ERROR 1: Pos = 45396150, insufficient arguments for Marked Content
# ERROR 1: Pos = 45396156, insufficient arguments for Marked Content
# ERROR 1: Pos = 45408790, insufficient arguments for Marked Content
# ERROR 1: Pos = 45421408, insufficient arguments for Marked Content
# ERROR 1: Pos = 45421413, insufficient arguments for Marked Content
# ERROR 1: Pos = 45424417, insufficient arguments for Marked Content
# ERROR 1: Pos = 45424575, insufficient arguments for Marked Content
# ERROR 1: Pos = 45424579, insufficient arguments for Marked Content
# ERROR 1: Pos = 45424652, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425189, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425193, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425539, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425554, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425775, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425779, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425897, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425927, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700946, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700952, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700954, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700954, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700975, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700982, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700984, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700992, insufficient arguments for Marked Content
# ERROR 1: Pos = 43700996, insufficient arguments for Marked Content
# ERROR 1: Pos = 43702887, insufficient arguments for Marked Content
# ERROR 1: Pos = 43702892, insufficient arguments for Marked Content
# ERROR 1: Pos = 43702928, insufficient arguments for Marked Content
# ERROR 1: Pos = 43702928, insufficient arguments for Marked Content
# ERROR 1: Pos = 43702930, insufficient arguments for Marked Content
# ERROR 1: Pos = 43741956, insufficient arguments for Marked Content
# ERROR 1: Pos = 43741962, insufficient arguments for Marked Content
# ERROR 1: Pos = 43744459, insufficient arguments for Marked Content
# ERROR 1: Pos = 43757387, insufficient arguments for Marked Content
# ERROR 1: Pos = 43757392, insufficient arguments for Marked Content
# ERROR 1: Pos = 43761799, insufficient arguments for Marked Content
# ERROR 1: Pos = 43762689, insufficient arguments for Marked Content
# ERROR 1: Pos = 44466698, insufficient arguments for Marked Content
# ERROR 1: Pos = 44466703, insufficient arguments for Marked Content
# ERROR 1: Pos = 44512720, insufficient arguments for Marked Content
# ERROR 1: Pos = 44513015, insufficient arguments for Marked Content
# ERROR 1: Pos = 44513019, insufficient arguments for Marked Content
# ERROR 1: Pos = 44555203, insufficient arguments for Marked Content
# ERROR 1: Pos = 44555209, insufficient arguments for Marked Content
# ERROR 1: Pos = 44802320, insufficient arguments for Marked Content
# ERROR 1: Pos = 45296305, insufficient arguments for Marked Content
# ERROR 1: Pos = 45296310, insufficient arguments for Marked Content
# ERROR 1: Pos = 45355064, insufficient arguments for Marked Content
# ERROR 1: Pos = 45355070, insufficient arguments for Marked Content
# ERROR 1: Pos = 45365882, insufficient arguments for Marked Content
# ERROR 1: Pos = 45370554, insufficient arguments for Marked Content
# ERROR 1: Pos = 45374725, insufficient arguments for Marked Content
# ERROR 1: Pos = 45385071, insufficient arguments for Marked Content
# ERROR 1: Pos = 45385076, insufficient arguments for Marked Content
# ERROR 1: Pos = 45388502, insufficient arguments for Marked Content
# ERROR 1: Pos = 45395284, insufficient arguments for Marked Content
# ERROR 1: Pos = 45395393, insufficient arguments for Marked Content
# ERROR 1: Pos = 45396150, insufficient arguments for Marked Content
# ERROR 1: Pos = 45396156, insufficient arguments for Marked Content
# ERROR 1: Pos = 45408790, insufficient arguments for Marked Content
# ERROR 1: Pos = 45421408, insufficient arguments for Marked Content
# ERROR 1: Pos = 45421413, insufficient arguments for Marked Content
# ERROR 1: Pos = 45424417, insufficient arguments for Marked Content
# ERROR 1: Pos = 45424575, insufficient arguments for Marked Content
# ERROR 1: Pos = 45424579, insufficient arguments for Marked Content
# ERROR 1: Pos = 45424652, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425189, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425193, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425539, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425554, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425775, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425779, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425897, insufficient arguments for Marked Content
# ERROR 1: Pos = 45425927, insufficient arguments for Marked Content
# Elaterite_Basin
# ERROR 1: Pos = 63779729, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779734, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779737, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779756, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779762, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779768, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779768, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779771, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779771, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779771, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779771, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779778, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779782, insufficient arguments for Marked Content
# ERROR 1: Pos = 63781667, insufficient arguments for Marked Content
# ERROR 1: Pos = 63781672, insufficient arguments for Marked Content
# ERROR 1: Pos = 63781707, insufficient arguments for Marked Content
# ERROR 1: Pos = 63781707, insufficient arguments for Marked Content
# ERROR 1: Pos = 63781709, insufficient arguments for Marked Content
# ERROR 1: Pos = 63856086, insufficient arguments for Marked Content
# ERROR 1: Pos = 63856089, insufficient arguments for Marked Content
# ERROR 1: Pos = 63857521, insufficient arguments for Marked Content
# ERROR 1: Pos = 63860013, insufficient arguments for Marked Content
# ERROR 1: Pos = 63860020, insufficient arguments for Marked Content
# ERROR 1: Pos = 63862708, insufficient arguments for Marked Content
# ERROR 1: Pos = 63864195, insufficient arguments for Marked Content
# ERROR 1: Pos = 65250959, insufficient arguments for Marked Content
# ERROR 1: Pos = 65250965, insufficient arguments for Marked Content
# ERROR 1: Pos = 65342974, insufficient arguments for Marked Content
# ERROR 1: Pos = 65343485, insufficient arguments for Marked Content
# ERROR 1: Pos = 65343489, insufficient arguments for Marked Content
# ERROR 1: Pos = 65363796, insufficient arguments for Marked Content
# ERROR 1: Pos = 65382278, insufficient arguments for Marked Content
# ERROR 1: Pos = 65382284, insufficient arguments for Marked Content
# ERROR 1: Pos = 65385579, insufficient arguments for Marked Content
# ERROR 1: Pos = 65616836, insufficient arguments for Marked Content
# ERROR 1: Pos = 66061632, insufficient arguments for Marked Content
# ERROR 1: Pos = 66061995, insufficient arguments for Marked Content
# ERROR 1: Pos = 66061998, insufficient arguments for Marked Content
# ERROR 1: Pos = 66155118, insufficient arguments for Marked Content
# ERROR 1: Pos = 66155124, insufficient arguments for Marked Content
# ERROR 1: Pos = 66187071, insufficient arguments for Marked Content
# ERROR 1: Pos = 66194818, insufficient arguments for Marked Content
# ERROR 1: Pos = 66201660, insufficient arguments for Marked Content
# ERROR 1: Pos = 66204097, insufficient arguments for Marked Content
# ERROR 1: Pos = 66234194, insufficient arguments for Marked Content
# ERROR 1: Pos = 66234250, insufficient arguments for Marked Content
# ERROR 1: Pos = 66237746, insufficient arguments for Marked Content
# ERROR 1: Pos = 66244191, insufficient arguments for Marked Content
# ERROR 1: Pos = 66244305, insufficient arguments for Marked Content
# ERROR 1: Pos = 66245019, insufficient arguments for Marked Content
# ERROR 1: Pos = 66245024, insufficient arguments for Marked Content
# ERROR 1: Pos = 66258920, insufficient arguments for Marked Content
# ERROR 1: Pos = 66261433, insufficient arguments for Marked Content
# ERROR 1: Pos = 66274012, insufficient arguments for Marked Content
# ERROR 1: Pos = 66274018, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277001, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277151, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277155, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277225, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277695, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277698, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277994, insufficient arguments for Marked Content
# ERROR 1: Pos = 66278007, insufficient arguments for Marked Content
# ERROR 1: Pos = 66278223, insufficient arguments for Marked Content
# ERROR 1: Pos = 66278227, insufficient arguments for Marked Content
# ERROR 1: Pos = 66278358, insufficient arguments for Marked Content
# ERROR 1: Pos = 66278389, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779729, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779734, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779737, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779756, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779762, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779768, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779768, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779771, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779771, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779771, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779771, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779778, insufficient arguments for Marked Content
# ERROR 1: Pos = 63779782, insufficient arguments for Marked Content
# ERROR 1: Pos = 63781667, insufficient arguments for Marked Content
# ERROR 1: Pos = 63781672, insufficient arguments for Marked Content
# ERROR 1: Pos = 63781707, insufficient arguments for Marked Content
# ERROR 1: Pos = 63781707, insufficient arguments for Marked Content
# ERROR 1: Pos = 63781709, insufficient arguments for Marked Content
# ERROR 1: Pos = 63856086, insufficient arguments for Marked Content
# ERROR 1: Pos = 63856089, insufficient arguments for Marked Content
# ERROR 1: Pos = 63857521, insufficient arguments for Marked Content
# ERROR 1: Pos = 63860013, insufficient arguments for Marked Content
# ERROR 1: Pos = 63860020, insufficient arguments for Marked Content
# ERROR 1: Pos = 63862708, insufficient arguments for Marked Content
# ERROR 1: Pos = 63864195, insufficient arguments for Marked Content
# ERROR 1: Pos = 65250959, insufficient arguments for Marked Content
# ERROR 1: Pos = 65250965, insufficient arguments for Marked Content
# ERROR 1: Pos = 65342974, insufficient arguments for Marked Content
# ERROR 1: Pos = 65343485, insufficient arguments for Marked Content
# ERROR 1: Pos = 65343489, insufficient arguments for Marked Content
# ERROR 1: Pos = 65363796, insufficient arguments for Marked Content
# ERROR 1: Pos = 65382278, insufficient arguments for Marked Content
# ERROR 1: Pos = 65382284, insufficient arguments for Marked Content
# ERROR 1: Pos = 65385579, insufficient arguments for Marked Content
# ERROR 1: Pos = 65616836, insufficient arguments for Marked Content
# ERROR 1: Pos = 66061632, insufficient arguments for Marked Content
# ERROR 1: Pos = 66061995, insufficient arguments for Marked Content
# ERROR 1: Pos = 66061998, insufficient arguments for Marked Content
# ERROR 1: Pos = 66155118, insufficient arguments for Marked Content
# ERROR 1: Pos = 66155124, insufficient arguments for Marked Content
# ERROR 1: Pos = 66187071, insufficient arguments for Marked Content
# ERROR 1: Pos = 66194818, insufficient arguments for Marked Content
# ERROR 1: Pos = 66201660, insufficient arguments for Marked Content
# ERROR 1: Pos = 66204097, insufficient arguments for Marked Content
# ERROR 1: Pos = 66234194, insufficient arguments for Marked Content
# ERROR 1: Pos = 66234250, insufficient arguments for Marked Content
# ERROR 1: Pos = 66237746, insufficient arguments for Marked Content
# ERROR 1: Pos = 66244191, insufficient arguments for Marked Content
# ERROR 1: Pos = 66244305, insufficient arguments for Marked Content
# ERROR 1: Pos = 66245019, insufficient arguments for Marked Content
# ERROR 1: Pos = 66245024, insufficient arguments for Marked Content
# ERROR 1: Pos = 66258920, insufficient arguments for Marked Content
# ERROR 1: Pos = 66261433, insufficient arguments for Marked Content
# ERROR 1: Pos = 66274012, insufficient arguments for Marked Content
# ERROR 1: Pos = 66274018, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277001, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277151, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277155, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277225, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277695, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277698, insufficient arguments for Marked Content
# ERROR 1: Pos = 66277994, insufficient arguments for Marked Content
# ERROR 1: Pos = 66278007, insufficient arguments for Marked Content
# ERROR 1: Pos = 66278223, insufficient arguments for Marked Content
# ERROR 1: Pos = 66278227, insufficient arguments for Marked Content
# ERROR 1: Pos = 66278358, insufficient arguments for Marked Content
# ERROR 1: Pos = 66278389, insufficient arguments for Marked Content
# Harts_Point_North
# ERROR 1: Pos = 50440539, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440544, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440547, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440547, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440567, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440574, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440579, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440579, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440579, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440581, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440581, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440581, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440587, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440591, insufficient arguments for Marked Content
# ERROR 1: Pos = 50442479, insufficient arguments for Marked Content
# ERROR 1: Pos = 50442484, insufficient arguments for Marked Content
# ERROR 1: Pos = 50442520, insufficient arguments for Marked Content
# ERROR 1: Pos = 50442520, insufficient arguments for Marked Content
# ERROR 1: Pos = 50442522, insufficient arguments for Marked Content
# ERROR 1: Pos = 50516538, insufficient arguments for Marked Content
# ERROR 1: Pos = 50516543, insufficient arguments for Marked Content
# ERROR 1: Pos = 50519407, insufficient arguments for Marked Content
# ERROR 1: Pos = 50521204, insufficient arguments for Marked Content
# ERROR 1: Pos = 50526842, insufficient arguments for Marked Content
# ERROR 1: Pos = 50526848, insufficient arguments for Marked Content
# ERROR 1: Pos = 50531731, insufficient arguments for Marked Content
# ERROR 1: Pos = 50533733, insufficient arguments for Marked Content
# ERROR 1: Pos = 51504645, insufficient arguments for Marked Content
# ERROR 1: Pos = 51504650, insufficient arguments for Marked Content
# ERROR 1: Pos = 51594412, insufficient arguments for Marked Content
# ERROR 1: Pos = 51594644, insufficient arguments for Marked Content
# ERROR 1: Pos = 51594647, insufficient arguments for Marked Content
# ERROR 1: Pos = 51596469, insufficient arguments for Marked Content
# ERROR 1: Pos = 51623261, insufficient arguments for Marked Content
# ERROR 1: Pos = 51623268, insufficient arguments for Marked Content
# ERROR 1: Pos = 51627610, insufficient arguments for Marked Content
# ERROR 1: Pos = 51874491, insufficient arguments for Marked Content
# ERROR 1: Pos = 52368019, insufficient arguments for Marked Content
# ERROR 1: Pos = 52368025, insufficient arguments for Marked Content
# ERROR 1: Pos = 52460751, insufficient arguments for Marked Content
# ERROR 1: Pos = 52460756, insufficient arguments for Marked Content
# ERROR 1: Pos = 52473047, insufficient arguments for Marked Content
# ERROR 1: Pos = 52478665, insufficient arguments for Marked Content
# ERROR 1: Pos = 52484298, insufficient arguments for Marked Content
# ERROR 1: Pos = 52484303, insufficient arguments for Marked Content
# ERROR 1: Pos = 52487762, insufficient arguments for Marked Content
# ERROR 1: Pos = 52494768, insufficient arguments for Marked Content
# ERROR 1: Pos = 52494880, insufficient arguments for Marked Content
# ERROR 1: Pos = 52495659, insufficient arguments for Marked Content
# ERROR 1: Pos = 52495665, insufficient arguments for Marked Content
# ERROR 1: Pos = 52509086, insufficient arguments for Marked Content
# ERROR 1: Pos = 52510276, insufficient arguments for Marked Content
# ERROR 1: Pos = 52522891, insufficient arguments for Marked Content
# ERROR 1: Pos = 52522896, insufficient arguments for Marked Content
# ERROR 1: Pos = 52525824, insufficient arguments for Marked Content
# ERROR 1: Pos = 52525973, insufficient arguments for Marked Content
# ERROR 1: Pos = 52525977, insufficient arguments for Marked Content
# ERROR 1: Pos = 52526044, insufficient arguments for Marked Content
# ERROR 1: Pos = 52526549, insufficient arguments for Marked Content
# ERROR 1: Pos = 52526553, insufficient arguments for Marked Content
# ERROR 1: Pos = 52526842, insufficient arguments for Marked Content
# ERROR 1: Pos = 52526857, insufficient arguments for Marked Content
# ERROR 1: Pos = 52527078, insufficient arguments for Marked Content
# ERROR 1: Pos = 52527081, insufficient arguments for Marked Content
# ERROR 1: Pos = 52527213, insufficient arguments for Marked Content
# ERROR 1: Pos = 52527243, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440539, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440544, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440547, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440547, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440567, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440574, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440579, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440579, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440579, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440581, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440581, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440581, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440587, insufficient arguments for Marked Content
# ERROR 1: Pos = 50440591, insufficient arguments for Marked Content
# ERROR 1: Pos = 50442479, insufficient arguments for Marked Content
# ERROR 1: Pos = 50442484, insufficient arguments for Marked Content
# ERROR 1: Pos = 50442520, insufficient arguments for Marked Content
# ERROR 1: Pos = 50442520, insufficient arguments for Marked Content
# ERROR 1: Pos = 50442522, insufficient arguments for Marked Content
# ERROR 1: Pos = 50516538, insufficient arguments for Marked Content
# ERROR 1: Pos = 50516543, insufficient arguments for Marked Content
# ERROR 1: Pos = 50519407, insufficient arguments for Marked Content
# ERROR 1: Pos = 50521204, insufficient arguments for Marked Content
# ERROR 1: Pos = 50526842, insufficient arguments for Marked Content
# ERROR 1: Pos = 50526848, insufficient arguments for Marked Content
# ERROR 1: Pos = 50531731, insufficient arguments for Marked Content
# ERROR 1: Pos = 50533733, insufficient arguments for Marked Content
# ERROR 1: Pos = 51504645, insufficient arguments for Marked Content
# ERROR 1: Pos = 51504650, insufficient arguments for Marked Content
# ERROR 1: Pos = 51594412, insufficient arguments for Marked Content
# ERROR 1: Pos = 51594644, insufficient arguments for Marked Content
# ERROR 1: Pos = 51594647, insufficient arguments for Marked Content
# ERROR 1: Pos = 51596469, insufficient arguments for Marked Content
# ERROR 1: Pos = 51623261, insufficient arguments for Marked Content
# ERROR 1: Pos = 51623268, insufficient arguments for Marked Content
# ERROR 1: Pos = 51627610, insufficient arguments for Marked Content
# ERROR 1: Pos = 51874491, insufficient arguments for Marked Content
# ERROR 1: Pos = 52368019, insufficient arguments for Marked Content
# ERROR 1: Pos = 52368025, insufficient arguments for Marked Content
# ERROR 1: Pos = 52460751, insufficient arguments for Marked Content
# ERROR 1: Pos = 52460756, insufficient arguments for Marked Content
# ERROR 1: Pos = 52473047, insufficient arguments for Marked Content
# ERROR 1: Pos = 52478665, insufficient arguments for Marked Content
# ERROR 1: Pos = 52484298, insufficient arguments for Marked Content
# ERROR 1: Pos = 52484303, insufficient arguments for Marked Content
# ERROR 1: Pos = 52487762, insufficient arguments for Marked Content
# ERROR 1: Pos = 52494768, insufficient arguments for Marked Content
# ERROR 1: Pos = 52494880, insufficient arguments for Marked Content
# ERROR 1: Pos = 52495659, insufficient arguments for Marked Content
# ERROR 1: Pos = 52495665, insufficient arguments for Marked Content
# ERROR 1: Pos = 52509086, insufficient arguments for Marked Content
# ERROR 1: Pos = 52510276, insufficient arguments for Marked Content
# ERROR 1: Pos = 52522891, insufficient arguments for Marked Content
# ERROR 1: Pos = 52522896, insufficient arguments for Marked Content
# ERROR 1: Pos = 52525824, insufficient arguments for Marked Content
# ERROR 1: Pos = 52525973, insufficient arguments for Marked Content
# ERROR 1: Pos = 52525977, insufficient arguments for Marked Content
# ERROR 1: Pos = 52526044, insufficient arguments for Marked Content
# ERROR 1: Pos = 52526549, insufficient arguments for Marked Content
# ERROR 1: Pos = 52526553, insufficient arguments for Marked Content
# ERROR 1: Pos = 52526842, insufficient arguments for Marked Content
# ERROR 1: Pos = 52526857, insufficient arguments for Marked Content
# ERROR 1: Pos = 52527078, insufficient arguments for Marked Content
# ERROR 1: Pos = 52527081, insufficient arguments for Marked Content
# ERROR 1: Pos = 52527213, insufficient arguments for Marked Content
# ERROR 1: Pos = 52527243, insufficient arguments for Marked Content
# Lockhart_Basin
# ERROR 1: Pos = 61209360, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209369, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209371, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209390, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209399, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209405, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209405, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209407, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209407, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209407, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209407, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209414, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209419, insufficient arguments for Marked Content
# ERROR 1: Pos = 61211305, insufficient arguments for Marked Content
# ERROR 1: Pos = 61211310, insufficient arguments for Marked Content
# ERROR 1: Pos = 61211347, insufficient arguments for Marked Content
# ERROR 1: Pos = 61211347, insufficient arguments for Marked Content
# ERROR 1: Pos = 61211349, insufficient arguments for Marked Content
# ERROR 1: Pos = 61245555, insufficient arguments for Marked Content
# ERROR 1: Pos = 61245561, insufficient arguments for Marked Content
# ERROR 1: Pos = 61254541, insufficient arguments for Marked Content
# ERROR 1: Pos = 61257221, insufficient arguments for Marked Content
# ERROR 1: Pos = 61264913, insufficient arguments for Marked Content
# ERROR 1: Pos = 61264919, insufficient arguments for Marked Content
# ERROR 1: Pos = 61269623, insufficient arguments for Marked Content
# ERROR 1: Pos = 61270642, insufficient arguments for Marked Content
# ERROR 1: Pos = 62584956, insufficient arguments for Marked Content
# ERROR 1: Pos = 62584963, insufficient arguments for Marked Content
# ERROR 1: Pos = 62678411, insufficient arguments for Marked Content
# ERROR 1: Pos = 62678713, insufficient arguments for Marked Content
# ERROR 1: Pos = 62678717, insufficient arguments for Marked Content
# ERROR 1: Pos = 62693788, insufficient arguments for Marked Content
# ERROR 1: Pos = 62735835, insufficient arguments for Marked Content
# ERROR 1: Pos = 62735841, insufficient arguments for Marked Content
# ERROR 1: Pos = 62737427, insufficient arguments for Marked Content
# ERROR 1: Pos = 62980712, insufficient arguments for Marked Content
# ERROR 1: Pos = 63467084, insufficient arguments for Marked Content
# ERROR 1: Pos = 63467090, insufficient arguments for Marked Content
# ERROR 1: Pos = 63560948, insufficient arguments for Marked Content
# ERROR 1: Pos = 63560954, insufficient arguments for Marked Content
# ERROR 1: Pos = 63578763, insufficient arguments for Marked Content
# ERROR 1: Pos = 63583396, insufficient arguments for Marked Content
# ERROR 1: Pos = 63587317, insufficient arguments for Marked Content
# ERROR 1: Pos = 63591497, insufficient arguments for Marked Content
# ERROR 1: Pos = 63599891, insufficient arguments for Marked Content
# ERROR 1: Pos = 63599896, insufficient arguments for Marked Content
# ERROR 1: Pos = 63603433, insufficient arguments for Marked Content
# ERROR 1: Pos = 63610270, insufficient arguments for Marked Content
# ERROR 1: Pos = 63610375, insufficient arguments for Marked Content
# ERROR 1: Pos = 63611107, insufficient arguments for Marked Content
# ERROR 1: Pos = 63611113, insufficient arguments for Marked Content
# ERROR 1: Pos = 63623757, insufficient arguments for Marked Content
# ERROR 1: Pos = 63636339, insufficient arguments for Marked Content
# ERROR 1: Pos = 63636344, insufficient arguments for Marked Content
# ERROR 1: Pos = 63639057, insufficient arguments for Marked Content
# ERROR 1: Pos = 63639218, insufficient arguments for Marked Content
# ERROR 1: Pos = 63639222, insufficient arguments for Marked Content
# ERROR 1: Pos = 63639296, insufficient arguments for Marked Content
# ERROR 1: Pos = 63639894, insufficient arguments for Marked Content
# ERROR 1: Pos = 63639898, insufficient arguments for Marked Content
# ERROR 1: Pos = 63640183, insufficient arguments for Marked Content
# ERROR 1: Pos = 63640199, insufficient arguments for Marked Content
# ERROR 1: Pos = 63640417, insufficient arguments for Marked Content
# ERROR 1: Pos = 63640421, insufficient arguments for Marked Content
# ERROR 1: Pos = 63640540, insufficient arguments for Marked Content
# ERROR 1: Pos = 63640565, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209360, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209369, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209371, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209390, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209399, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209405, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209405, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209407, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209407, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209407, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209407, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209414, insufficient arguments for Marked Content
# ERROR 1: Pos = 61209419, insufficient arguments for Marked Content
# ERROR 1: Pos = 61211305, insufficient arguments for Marked Content
# ERROR 1: Pos = 61211310, insufficient arguments for Marked Content
# ERROR 1: Pos = 61211347, insufficient arguments for Marked Content
# ERROR 1: Pos = 61211347, insufficient arguments for Marked Content
# ERROR 1: Pos = 61211349, insufficient arguments for Marked Content
# ERROR 1: Pos = 61245555, insufficient arguments for Marked Content
# ERROR 1: Pos = 61245561, insufficient arguments for Marked Content
# ERROR 1: Pos = 61254541, insufficient arguments for Marked Content
# ERROR 1: Pos = 61257221, insufficient arguments for Marked Content
# ERROR 1: Pos = 61264913, insufficient arguments for Marked Content
# ERROR 1: Pos = 61264919, insufficient arguments for Marked Content
# ERROR 1: Pos = 61269623, insufficient arguments for Marked Content
# ERROR 1: Pos = 61270642, insufficient arguments for Marked Content
# ERROR 1: Pos = 62584956, insufficient arguments for Marked Content
# ERROR 1: Pos = 62584963, insufficient arguments for Marked Content
# ERROR 1: Pos = 62678411, insufficient arguments for Marked Content
# ERROR 1: Pos = 62678713, insufficient arguments for Marked Content
# ERROR 1: Pos = 62678717, insufficient arguments for Marked Content
# ERROR 1: Pos = 62693788, insufficient arguments for Marked Content
# ERROR 1: Pos = 62735835, insufficient arguments for Marked Content
# ERROR 1: Pos = 62735841, insufficient arguments for Marked Content
# ERROR 1: Pos = 62737427, insufficient arguments for Marked Content
# ERROR 1: Pos = 62980712, insufficient arguments for Marked Content
# ERROR 1: Pos = 63467084, insufficient arguments for Marked Content
# ERROR 1: Pos = 63467090, insufficient arguments for Marked Content
# ERROR 1: Pos = 63560948, insufficient arguments for Marked Content
# ERROR 1: Pos = 63560954, insufficient arguments for Marked Content
# ERROR 1: Pos = 63578763, insufficient arguments for Marked Content
# ERROR 1: Pos = 63583396, insufficient arguments for Marked Content
# ERROR 1: Pos = 63587317, insufficient arguments for Marked Content
# ERROR 1: Pos = 63591497, insufficient arguments for Marked Content
# ERROR 1: Pos = 63599891, insufficient arguments for Marked Content
# ERROR 1: Pos = 63599896, insufficient arguments for Marked Content
# ERROR 1: Pos = 63603433, insufficient arguments for Marked Content
# ERROR 1: Pos = 63610270, insufficient arguments for Marked Content
# ERROR 1: Pos = 63610375, insufficient arguments for Marked Content
# ERROR 1: Pos = 63611107, insufficient arguments for Marked Content
# ERROR 1: Pos = 63611113, insufficient arguments for Marked Content
# ERROR 1: Pos = 63623757, insufficient arguments for Marked Content
# ERROR 1: Pos = 63636339, insufficient arguments for Marked Content
# ERROR 1: Pos = 63636344, insufficient arguments for Marked Content
# ERROR 1: Pos = 63639057, insufficient arguments for Marked Content
# ERROR 1: Pos = 63639218, insufficient arguments for Marked Content
# ERROR 1: Pos = 63639222, insufficient arguments for Marked Content
# ERROR 1: Pos = 63639296, insufficient arguments for Marked Content
# ERROR 1: Pos = 63639894, insufficient arguments for Marked Content
# ERROR 1: Pos = 63639898, insufficient arguments for Marked Content
# ERROR 1: Pos = 63640183, insufficient arguments for Marked Content
# ERROR 1: Pos = 63640199, insufficient arguments for Marked Content
# ERROR 1: Pos = 63640417, insufficient arguments for Marked Content
# ERROR 1: Pos = 63640421, insufficient arguments for Marked Content
# ERROR 1: Pos = 63640540, insufficient arguments for Marked Content
# ERROR 1: Pos = 63640565, insufficient arguments for Marked Content
# Monument_Basin
# ERROR 1: Pos = 80646586, insufficient arguments for Marked Content
# ERROR 1: Pos = 80646586, insufficient arguments for Marked Content
# ERROR 1: Pos = 80646607, insufficient arguments for Marked Content
# ERROR 1: Pos = 80646615, insufficient arguments for Marked Content
# ERROR 1: Pos = 80646621, insufficient arguments for Marked Content
# ERROR 1: Pos = 80646621, insufficient arguments for Marked Content
# ERROR 1: Pos = 80646623, insufficient arguments for Marked Content
# ERROR 1: Pos = 80646623, insufficient arguments for Marked Content
# ERROR 1: Pos = 80646623, insufficient arguments for Marked Content
# ERROR 1: Pos = 80646623, insufficient arguments for Marked Content
# ERROR 1: Pos = 80646630, insufficient arguments for Marked Content
# ERROR 1: Pos = 80646634, insufficient arguments for Marked Content
# ERROR 1: Pos = 80648526, insufficient arguments for Marked Content
# ERROR 1: Pos = 80648531, insufficient arguments for Marked Content
# ERROR 1: Pos = 80648566, insufficient arguments for Marked Content
# ERROR 1: Pos = 80648566, insufficient arguments for Marked Content
# ERROR 1: Pos = 80648569, insufficient arguments for Marked Content
# ERROR 1: Pos = 80652180, insufficient arguments for Marked Content
# ERROR 1: Pos = 80652186, insufficient arguments for Marked Content
# ERROR 1: Pos = 80674124, insufficient arguments for Marked Content
# ERROR 1: Pos = 80679586, insufficient arguments for Marked Content
# ERROR 1: Pos = 80680470, insufficient arguments for Marked Content
# ERROR 1: Pos = 80680474, insufficient arguments for Marked Content
# ERROR 1: Pos = 80683758, insufficient arguments for Marked Content
# ERROR 1: Pos = 80684941, insufficient arguments for Marked Content
# ERROR 1: Pos = 82407651, insufficient arguments for Marked Content
# ERROR 1: Pos = 82407656, insufficient arguments for Marked Content
# ERROR 1: Pos = 82475574, insufficient arguments for Marked Content
# ERROR 1: Pos = 82475579, insufficient arguments for Marked Content
# ERROR 1: Pos = 82496320, insufficient arguments for Marked Content
# ERROR 1: Pos = 82514394, insufficient arguments for Marked Content
# ERROR 1: Pos = 82514400, insufficient arguments for Marked Content
# ERROR 1: Pos = 82516192, insufficient arguments for Marked Content
# ERROR 1: Pos = 82751358, insufficient arguments for Marked Content
# ERROR 1: Pos = 83220494, insufficient arguments for Marked Content
# ERROR 1: Pos = 83220790, insufficient arguments for Marked Content
# ERROR 1: Pos = 83220794, insufficient arguments for Marked Content
# ERROR 1: Pos = 83349560, insufficient arguments for Marked Content
# ERROR 1: Pos = 83349566, insufficient arguments for Marked Content
# ERROR 1: Pos = 83377853, insufficient arguments for Marked Content
# ERROR 1: Pos = 83380508, insufficient arguments for Marked Content
# ERROR 1: Pos = 83384415, insufficient arguments for Marked Content
# ERROR 1: Pos = 83397453, insufficient arguments for Marked Content
# ERROR 1: Pos = 83423676, insufficient arguments for Marked Content
# ERROR 1: Pos = 83423682, insufficient arguments for Marked Content
# ERROR 1: Pos = 83427201, insufficient arguments for Marked Content
# ERROR 1: Pos = 83434040, insufficient arguments for Marked Content
# ERROR 1: Pos = 83434144, insufficient arguments for Marked Content
# ERROR 1: Pos = 83434919, insufficient arguments for Marked Content
# ERROR 1: Pos = 83434925, insufficient arguments for Marked Content
# ERROR 1: Pos = 83449718, insufficient arguments for Marked Content
# ERROR 1: Pos = 83462379, insufficient arguments for Marked Content
# ERROR 1: Pos = 83462385, insufficient arguments for Marked Content
# ERROR 1: Pos = 83465263, insufficient arguments for Marked Content
# ERROR 1: Pos = 83465427, insufficient arguments for Marked Content
# ERROR 1: Pos = 83465431, insufficient arguments for Marked Content
# ...
# ERROR 1: Pos = 83423676, insufficient arguments for Marked Content
# ERROR 1: Pos = 83423682, insufficient arguments for Marked Content
# ERROR 1: Pos = 83427201, insufficient arguments for Marked Content
# ERROR 1: Pos = 83434040, insufficient arguments for Marked Content
# ERROR 1: Pos = 83434144, insufficient arguments for Marked Content
# ERROR 1: Pos = 83434919, insufficient arguments for Marked Content
# ERROR 1: Pos = 83434925, insufficient arguments for Marked Content
# ERROR 1: Pos = 83449718, insufficient arguments for Marked Content
# ERROR 1: Pos = 83462379, insufficient arguments for Marked Content
# ERROR 1: Pos = 83462385, insufficient arguments for Marked Content
# ERROR 1: Pos = 83465263, insufficient arguments for Marked Content
# ERROR 1: Pos = 83465427, insufficient arguments for Marked Content
# ERROR 1: Pos = 83465431, insufficient arguments for Marked Content
# ERROR 1: Pos = 83465508, insufficient arguments for Marked Content
# ERROR 1: Pos = 83466075, insufficient arguments for Marked Content
# ERROR 1: Pos = 83466079, insufficient arguments for Marked Content
# ERROR 1: Pos = 83466374, insufficient arguments for Marked Content
# ERROR 1: Pos = 83466388, insufficient arguments for Marked Content
# ERROR 1: Pos = 83466608, insufficient arguments for Marked Content
# ERROR 1: Pos = 83466611, insufficient arguments for Marked Content
# ERROR 1: Pos = 83466722, insufficient arguments for Marked Content
# ERROR 1: Pos = 83466751, insufficient arguments for Marked Content
# North_Six-shooter_Peak
# ERROR 1: Pos = 46921869, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921869, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921874, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921889, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921897, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921903, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921903, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921905, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921905, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921905, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921905, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921913, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921917, insufficient arguments for Marked Content
# ERROR 1: Pos = 46923809, insufficient arguments for Marked Content
# ERROR 1: Pos = 46923814, insufficient arguments for Marked Content
# ERROR 1: Pos = 46923851, insufficient arguments for Marked Content
# ERROR 1: Pos = 46923851, insufficient arguments for Marked Content
# ERROR 1: Pos = 46923853, insufficient arguments for Marked Content
# ERROR 1: Pos = 46926403, insufficient arguments for Marked Content
# ERROR 1: Pos = 46926409, insufficient arguments for Marked Content
# ERROR 1: Pos = 46929720, insufficient arguments for Marked Content
# ERROR 1: Pos = 46931244, insufficient arguments for Marked Content
# ERROR 1: Pos = 46931251, insufficient arguments for Marked Content
# ERROR 1: Pos = 46935809, insufficient arguments for Marked Content
# ERROR 1: Pos = 46938127, insufficient arguments for Marked Content
# ERROR 1: Pos = 47797319, insufficient arguments for Marked Content
# ERROR 1: Pos = 47797324, insufficient arguments for Marked Content
# ERROR 1: Pos = 47897553, insufficient arguments for Marked Content
# ERROR 1: Pos = 47897559, insufficient arguments for Marked Content
# ERROR 1: Pos = 47908145, insufficient arguments for Marked Content
# ERROR 1: Pos = 47941278, insufficient arguments for Marked Content
# ERROR 1: Pos = 47941283, insufficient arguments for Marked Content
# ERROR 1: Pos = 47948404, insufficient arguments for Marked Content
# ERROR 1: Pos = 48191326, insufficient arguments for Marked Content
# ERROR 1: Pos = 48676931, insufficient arguments for Marked Content
# ERROR 1: Pos = 48677115, insufficient arguments for Marked Content
# ERROR 1: Pos = 48677118, insufficient arguments for Marked Content
# ERROR 1: Pos = 48743591, insufficient arguments for Marked Content
# ERROR 1: Pos = 48743597, insufficient arguments for Marked Content
# ERROR 1: Pos = 48752652, insufficient arguments for Marked Content
# ERROR 1: Pos = 48761678, insufficient arguments for Marked Content
# ERROR 1: Pos = 48765644, insufficient arguments for Marked Content
# ERROR 1: Pos = 48778188, insufficient arguments for Marked Content
# ERROR 1: Pos = 48786093, insufficient arguments for Marked Content
# ERROR 1: Pos = 48786099, insufficient arguments for Marked Content
# ERROR 1: Pos = 48789601, insufficient arguments for Marked Content
# ERROR 1: Pos = 48796322, insufficient arguments for Marked Content
# ERROR 1: Pos = 48796430, insufficient arguments for Marked Content
# ERROR 1: Pos = 48797159, insufficient arguments for Marked Content
# ERROR 1: Pos = 48797165, insufficient arguments for Marked Content
# ERROR 1: Pos = 48811910, insufficient arguments for Marked Content
# ERROR 1: Pos = 48814709, insufficient arguments for Marked Content
# ERROR 1: Pos = 48827404, insufficient arguments for Marked Content
# ERROR 1: Pos = 48827410, insufficient arguments for Marked Content
# ERROR 1: Pos = 48830157, insufficient arguments for Marked Content
# ERROR 1: Pos = 48830314, insufficient arguments for Marked Content
# ERROR 1: Pos = 48830318, insufficient arguments for Marked Content
# ERROR 1: Pos = 48830390, insufficient arguments for Marked Content
# ERROR 1: Pos = 48830890, insufficient arguments for Marked Content
# ERROR 1: Pos = 48830894, insufficient arguments for Marked Content
# ERROR 1: Pos = 48831180, insufficient arguments for Marked Content
# ERROR 1: Pos = 48831197, insufficient arguments for Marked Content
# ERROR 1: Pos = 48831416, insufficient arguments for Marked Content
# ERROR 1: Pos = 48831420, insufficient arguments for Marked Content
# ERROR 1: Pos = 48831555, insufficient arguments for Marked Content
# ERROR 1: Pos = 48831588, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921869, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921869, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921874, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921889, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921897, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921903, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921903, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921905, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921905, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921905, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921905, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921913, insufficient arguments for Marked Content
# ERROR 1: Pos = 46921917, insufficient arguments for Marked Content
# ERROR 1: Pos = 46923809, insufficient arguments for Marked Content
# ERROR 1: Pos = 46923814, insufficient arguments for Marked Content
# ERROR 1: Pos = 46923851, insufficient arguments for Marked Content
# ERROR 1: Pos = 46923851, insufficient arguments for Marked Content
# ERROR 1: Pos = 46923853, insufficient arguments for Marked Content
# ERROR 1: Pos = 46926403, insufficient arguments for Marked Content
# ERROR 1: Pos = 46926409, insufficient arguments for Marked Content
# ERROR 1: Pos = 46929720, insufficient arguments for Marked Content
# ERROR 1: Pos = 46931244, insufficient arguments for Marked Content
# ERROR 1: Pos = 46931251, insufficient arguments for Marked Content
# ERROR 1: Pos = 46935809, insufficient arguments for Marked Content
# ERROR 1: Pos = 46938127, insufficient arguments for Marked Content
# ERROR 1: Pos = 47797319, insufficient arguments for Marked Content
# ERROR 1: Pos = 47797324, insufficient arguments for Marked Content
# ERROR 1: Pos = 47897553, insufficient arguments for Marked Content
# ERROR 1: Pos = 47897559, insufficient arguments for Marked Content
# ERROR 1: Pos = 47908145, insufficient arguments for Marked Content
# ERROR 1: Pos = 47941278, insufficient arguments for Marked Content
# ERROR 1: Pos = 47941283, insufficient arguments for Marked Content
# ERROR 1: Pos = 47948404, insufficient arguments for Marked Content
# ERROR 1: Pos = 48191326, insufficient arguments for Marked Content
# ERROR 1: Pos = 48676931, insufficient arguments for Marked Content
# ERROR 1: Pos = 48677115, insufficient arguments for Marked Content
# ERROR 1: Pos = 48677118, insufficient arguments for Marked Content
# ERROR 1: Pos = 48743591, insufficient arguments for Marked Content
# ERROR 1: Pos = 48743597, insufficient arguments for Marked Content
# ERROR 1: Pos = 48752652, insufficient arguments for Marked Content
# ERROR 1: Pos = 48761678, insufficient arguments for Marked Content
# ERROR 1: Pos = 48765644, insufficient arguments for Marked Content
# ERROR 1: Pos = 48778188, insufficient arguments for Marked Content
# ERROR 1: Pos = 48786093, insufficient arguments for Marked Content
# ERROR 1: Pos = 48786099, insufficient arguments for Marked Content
# ERROR 1: Pos = 48789601, insufficient arguments for Marked Content
# ERROR 1: Pos = 48796322, insufficient arguments for Marked Content
# ERROR 1: Pos = 48796430, insufficient arguments for Marked Content
# ERROR 1: Pos = 48797159, insufficient arguments for Marked Content
# ERROR 1: Pos = 48797165, insufficient arguments for Marked Content
# ERROR 1: Pos = 48811910, insufficient arguments for Marked Content
# ERROR 1: Pos = 48814709, insufficient arguments for Marked Content
# ERROR 1: Pos = 48827404, insufficient arguments for Marked Content
# ERROR 1: Pos = 48827410, insufficient arguments for Marked Content
# ERROR 1: Pos = 48830157, insufficient arguments for Marked Content
# ERROR 1: Pos = 48830314, insufficient arguments for Marked Content
# ERROR 1: Pos = 48830318, insufficient arguments for Marked Content
# ERROR 1: Pos = 48830390, insufficient arguments for Marked Content
# ERROR 1: Pos = 48830890, insufficient arguments for Marked Content
# ERROR 1: Pos = 48830894, insufficient arguments for Marked Content
# ERROR 1: Pos = 48831180, insufficient arguments for Marked Content
# ERROR 1: Pos = 48831197, insufficient arguments for Marked Content
# ERROR 1: Pos = 48831416, insufficient arguments for Marked Content
# ERROR 1: Pos = 48831420, insufficient arguments for Marked Content
# ERROR 1: Pos = 48831555, insufficient arguments for Marked Content
# ERROR 1: Pos = 48831588, insufficient arguments for Marked Content
# Spanish_Bottom
# ERROR 1: Pos = 86033405, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033411, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033413, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033429, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033429, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033438, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033440, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033443, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033443, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033443, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033443, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033443, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033451, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033455, insufficient arguments for Marked Content
# ERROR 1: Pos = 86035346, insufficient arguments for Marked Content
# ERROR 1: Pos = 86035352, insufficient arguments for Marked Content
# ERROR 1: Pos = 86035388, insufficient arguments for Marked Content
# ERROR 1: Pos = 86035388, insufficient arguments for Marked Content
# ERROR 1: Pos = 86035390, insufficient arguments for Marked Content
# ERROR 1: Pos = 86070193, insufficient arguments for Marked Content
# ERROR 1: Pos = 86075239, insufficient arguments for Marked Content
# ERROR 1: Pos = 86075246, insufficient arguments for Marked Content
# ERROR 1: Pos = 86078660, insufficient arguments for Marked Content
# ERROR 1: Pos = 86081303, insufficient arguments for Marked Content
# ERROR 1: Pos = 87916280, insufficient arguments for Marked Content
# ERROR 1: Pos = 87916285, insufficient arguments for Marked Content
# ERROR 1: Pos = 87994266, insufficient arguments for Marked Content
# ERROR 1: Pos = 87994476, insufficient arguments for Marked Content
# ERROR 1: Pos = 87994480, insufficient arguments for Marked Content
# ERROR 1: Pos = 88033215, insufficient arguments for Marked Content
# ERROR 1: Pos = 88041093, insufficient arguments for Marked Content
# ERROR 1: Pos = 88041098, insufficient arguments for Marked Content
# ERROR 1: Pos = 88459302, insufficient arguments for Marked Content
# ERROR 1: Pos = 88917088, insufficient arguments for Marked Content
# ERROR 1: Pos = 88917349, insufficient arguments for Marked Content
# ERROR 1: Pos = 88917352, insufficient arguments for Marked Content
# ERROR 1: Pos = 89069839, insufficient arguments for Marked Content
# ERROR 1: Pos = 89069845, insufficient arguments for Marked Content
# ERROR 1: Pos = 89137372, insufficient arguments for Marked Content
# ERROR 1: Pos = 89141333, insufficient arguments for Marked Content
# ERROR 1: Pos = 89160308, insufficient arguments for Marked Content
# ERROR 1: Pos = 89162986, insufficient arguments for Marked Content
# ERROR 1: Pos = 89176313, insufficient arguments for Marked Content
# ERROR 1: Pos = 89224640, insufficient arguments for Marked Content
# ERROR 1: Pos = 89224645, insufficient arguments for Marked Content
# ERROR 1: Pos = 89228089, insufficient arguments for Marked Content
# ERROR 1: Pos = 89234904, insufficient arguments for Marked Content
# ERROR 1: Pos = 89235013, insufficient arguments for Marked Content
# ERROR 1: Pos = 89235752, insufficient arguments for Marked Content
# ERROR 1: Pos = 89235758, insufficient arguments for Marked Content
# ERROR 1: Pos = 89252408, insufficient arguments for Marked Content
# ERROR 1: Pos = 89257552, insufficient arguments for Marked Content
# ERROR 1: Pos = 89270111, insufficient arguments for Marked Content
# ERROR 1: Pos = 89270117, insufficient arguments for Marked Content
# ERROR 1: Pos = 89273097, insufficient arguments for Marked Content
# ERROR 1: Pos = 89273245, insufficient arguments for Marked Content
# ERROR 1: Pos = 89273248, insufficient arguments for Marked Content
# ERROR 1: Pos = 89273317, insufficient arguments for Marked Content
# ERROR 1: Pos = 89273765, insufficient arguments for Marked Content
# ERROR 1: Pos = 89273769, insufficient arguments for Marked Content
# ERROR 1: Pos = 89274056, insufficient arguments for Marked Content
# ERROR 1: Pos = 89274071, insufficient arguments for Marked Content
# ERROR 1: Pos = 89274287, insufficient arguments for Marked Content
# ERROR 1: Pos = 89274292, insufficient arguments for Marked Content
# ERROR 1: Pos = 89274426, insufficient arguments for Marked Content
# ERROR 1: Pos = 89274458, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033405, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033411, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033413, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033429, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033429, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033438, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033440, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033443, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033443, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033443, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033443, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033443, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033451, insufficient arguments for Marked Content
# ERROR 1: Pos = 86033455, insufficient arguments for Marked Content
# More than 1000 errors or warnings have been reported. No more will be reported from now.
# The_Loop
# Turks_Head
# 38.25
# Elaterite_Basin, Harts_Point_North, North_Six-shooter_Peak, Spanish_Bottom, The_Loop
# 38.375
# Cleopatras_Chair, Eightmile_Rock, Lockhart_Basin, Monument_Basin, Turks_Head
