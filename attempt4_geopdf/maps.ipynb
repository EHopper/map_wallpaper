# %%
import glob

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, ImageEnhance

from osgeo import gdal
gdal.SetConfigOption('GDAL_PDF_LAYERS', 'Map_Frame')

# %%
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Bloomville_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Hobart_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Roxbury_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Prattsville_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Ashland_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Hensonville_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Freehold_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Leeds_20190926_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Hudson_North_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Andes_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Margaretville_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Fleischmanns_20190925_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_West_Kill_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Lexington_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Hunter_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Kaaterskill_Clove_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Cementon_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Hudson_South_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Lewbeach_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Arena_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Seager_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Shandaken_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Phoenicia_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Bearsville_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Woodstock_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Saugerties_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Clermont_20190919_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Livingston_Manor_20190916_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Willowemoc_20190916_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Claryville_20190916_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Peekamoose_Mountain_20190916_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_West_Shokan_20190916_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Ashokan_20190916_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Kingston_West_20190916_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Kingston_East_20190930_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Rock_City_20190930_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Liberty_West_20190916_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Liberty_East_20190923_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Grahamsville_20190916_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Rondout_Reservoir_20190916_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Kerhonkson_20190916_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Mohonk_Lake_20190916_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Rosendale_20190923_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Hyde_Park_20190927_TM_geo.pdf
# !wget https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Salt_Point_20190927_TM_geo.pdf
# Out:
# --2022-11-20 18:11:16--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Bloomville_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.196.18, 52.92.178.233, 52.218.201.74, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.196.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59844419 (57M) [application/pdf]
# Saving to: ‘NY_Bloomville_20190919_TM_geo.pdf’
#
# NY_Bloomville_20190 100%[===================>]  57.07M  5.13MB/s    in 21s
#
# 2022-11-20 18:11:37 (2.71 MB/s) - ‘NY_Bloomville_20190919_TM_geo.pdf’ saved [59844419/59844419]
#
# --2022-11-20 18:11:38--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Hobart_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.192.113, 52.218.216.74, 52.218.251.35, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.192.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60162334 (57M) [application/pdf]
# Saving to: ‘NY_Hobart_20190919_TM_geo.pdf’
#
# NY_Hobart_20190919_ 100%[===================>]  57.38M  10.8MB/s    in 17s
#
# 2022-11-20 18:11:55 (3.45 MB/s) - ‘NY_Hobart_20190919_TM_geo.pdf’ saved [60162334/60162334]
#
# --2022-11-20 18:11:55--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Roxbury_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.237.171, 52.218.197.131, 52.218.228.3, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.237.171|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62207263 (59M) [application/pdf]
# Saving to: ‘NY_Roxbury_20190919_TM_geo.pdf’
#
# NY_Roxbury_20190919 100%[===================>]  59.33M  11.2MB/s    in 17s
#
# 2022-11-20 18:12:13 (3.52 MB/s) - ‘NY_Roxbury_20190919_TM_geo.pdf’ saved [62207263/62207263]
#
# --2022-11-20 18:12:13--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Prattsville_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.251.131, 52.92.177.17, 52.218.216.251, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.251.131|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62325179 (59M) [application/pdf]
# Saving to: ‘NY_Prattsville_20190919_TM_geo.pdf’
#
# NY_Prattsville_2019 100%[===================>]  59.44M  17.5MB/s    in 4.1s
#
# 2022-11-20 18:12:18 (14.6 MB/s) - ‘NY_Prattsville_20190919_TM_geo.pdf’ saved [62325179/62325179]
#
# --2022-11-20 18:12:18--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Ashland_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.194.57, 52.92.177.17, 52.218.216.251, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.194.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62109789 (59M) [application/pdf]
# Saving to: ‘NY_Ashland_20190919_TM_geo.pdf’
#
# NY_Ashland_20190919 100%[===================>]  59.23M  11.3MB/s    in 17s
#
# 2022-11-20 18:12:35 (3.56 MB/s) - ‘NY_Ashland_20190919_TM_geo.pdf’ saved [62109789/62109789]
#
# --2022-11-20 18:12:36--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Hensonville_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.168.187, 52.92.132.137, 52.218.252.195, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.168.187|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64942959 (62M) [application/pdf]
# Saving to: ‘NY_Hensonville_20190919_TM_geo.pdf’
#
# NY_Hensonville_2019 100%[===================>]  61.93M  11.7MB/s    in 17s
#
# 2022-11-20 18:12:53 (3.64 MB/s) - ‘NY_Hensonville_20190919_TM_geo.pdf’ saved [64942959/64942959]
#
# --2022-11-20 18:12:54--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Freehold_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.136.75, 52.218.232.235, 52.218.242.227, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.136.75|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61246715 (58M) [application/pdf]
# Saving to: ‘NY_Freehold_20190919_TM_geo.pdf’
#
# NY_Freehold_2019091 100%[===================>]  58.41M  17.3MB/s    in 4.0s
#
# 2022-11-20 18:12:58 (14.6 MB/s) - ‘NY_Freehold_20190919_TM_geo.pdf’ saved [61246715/61246715]
#
# --2022-11-20 18:12:58--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Leeds_20190926_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.229.83, 52.218.232.235, 52.218.242.227, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.229.83|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60745299 (58M) [application/pdf]
# Saving to: ‘NY_Leeds_20190926_TM_geo.pdf’
#
# NY_Leeds_20190926_T 100%[===================>]  57.93M  9.29MB/s    in 17s
#
# 2022-11-20 18:13:17 (3.33 MB/s) - ‘NY_Leeds_20190926_TM_geo.pdf’ saved [60745299/60745299]
#
# --2022-11-20 18:13:17--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Hudson_North_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.194.25, 52.218.229.27, 52.92.195.249, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.194.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53660202 (51M) [application/pdf]
# Saving to: ‘NY_Hudson_North_20190919_TM_geo.pdf’
#
# NY_Hudson_North_201 100%[===================>]  51.17M  16.2MB/s    in 3.6s
#
# 2022-11-20 18:13:21 (14.3 MB/s) - ‘NY_Hudson_North_20190919_TM_geo.pdf’ saved [53660202/53660202]
#
# --2022-11-20 18:13:21--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Andes_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.178.43, 52.218.229.27, 52.92.195.249, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.178.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61528889 (59M) [application/pdf]
# Saving to: ‘NY_Andes_20190919_TM_geo.pdf’
#
# NY_Andes_20190919_T 100%[===================>]  58.68M  14.7MB/s    in 5.9s
#
# 2022-11-20 18:13:28 (9.95 MB/s) - ‘NY_Andes_20190919_TM_geo.pdf’ saved [61528889/61528889]
#
# --2022-11-20 18:13:28--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Margaretville_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.161.73, 52.218.229.27, 52.218.245.234, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.161.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62653260 (60M) [application/pdf]
# Saving to: ‘NY_Margaretville_20190919_TM_geo.pdf’
#
# NY_Margaretville_20 100%[===================>]  59.75M  7.74MB/s    in 10s
#
# 2022-11-20 18:13:39 (5.80 MB/s) - ‘NY_Margaretville_20190919_TM_geo.pdf’ saved [62653260/62653260]
#
# --2022-11-20 18:13:39--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Fleischmanns_20190925_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.181.203, 52.92.149.121, 52.92.193.169, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.181.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64173429 (61M) [application/pdf]
# Saving to: ‘NY_Fleischmanns_20190925_TM_geo.pdf’
#
# NY_Fleischmanns_201 100%[===================>]  61.20M  17.0MB/s    in 4.4s
#
# 2022-11-20 18:13:44 (13.8 MB/s) - ‘NY_Fleischmanns_20190925_TM_geo.pdf’ saved [64173429/64173429]
#
# --2022-11-20 18:13:44--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_West_Kill_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.163.17, 52.92.149.121, 52.92.193.169, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.163.17|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65707959 (63M) [application/pdf]
# Saving to: ‘NY_West_Kill_20190919_TM_geo.pdf’
#
# NY_West_Kill_201909 100%[===================>]  62.66M  11.6MB/s    in 17s
#
# 2022-11-20 18:14:02 (3.70 MB/s) - ‘NY_West_Kill_20190919_TM_geo.pdf’ saved [65707959/65707959]
#
# --2022-11-20 18:14:02--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Lexington_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.212.106, 52.92.194.41, 52.92.194.137, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.212.106|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65775421 (63M) [application/pdf]
# Saving to: ‘NY_Lexington_20190919_TM_geo.pdf’
#
# NY_Lexington_201909 100%[===================>]  62.73M  17.5MB/s    in 4.3s
#
# 2022-11-20 18:14:07 (14.7 MB/s) - ‘NY_Lexington_20190919_TM_geo.pdf’ saved [65775421/65775421]
#
# --2022-11-20 18:14:07--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Hunter_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.194.137, 52.92.194.41, 52.218.232.162, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.194.137|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65337333 (62M) [application/pdf]
# Saving to: ‘NY_Hunter_20190919_TM_geo.pdf’
#
# NY_Hunter_20190919_ 100%[===================>]  62.31M  17.3MB/s    in 4.3s
#
# 2022-11-20 18:14:12 (14.5 MB/s) - ‘NY_Hunter_20190919_TM_geo.pdf’ saved [65337333/65337333]
#
# --2022-11-20 18:14:12--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Kaaterskill_Clove_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.221.243, 52.218.244.210, 52.218.232.162, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.221.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62272700 (59M) [application/pdf]
# Saving to: ‘NY_Kaaterskill_Clove_20190919_TM_geo.pdf’
#
# NY_Kaaterskill_Clov 100%[===================>]  59.39M  10.7MB/s    in 17s
#
# 2022-11-20 18:14:30 (3.49 MB/s) - ‘NY_Kaaterskill_Clove_20190919_TM_geo.pdf’ saved [62272700/62272700]
#
# --2022-11-20 18:14:30--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Cementon_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.183.73, 52.218.240.146, 52.218.216.58, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.183.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59837804 (57M) [application/pdf]
# Saving to: ‘NY_Cementon_20190919_TM_geo.pdf’
#
# NY_Cementon_2019091 100%[===================>]  57.07M  17.2MB/s    in 4.0s
#
# 2022-11-20 18:14:35 (14.4 MB/s) - ‘NY_Cementon_20190919_TM_geo.pdf’ saved [59837804/59837804]
#
# --2022-11-20 18:14:35--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Hudson_South_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.154.51, 52.218.240.146, 52.218.216.58, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.154.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54686460 (52M) [application/pdf]
# Saving to: ‘NY_Hudson_South_20190919_TM_geo.pdf’
#
# NY_Hudson_South_201 100%[===================>]  52.15M  10.1MB/s    in 16s
#
# 2022-11-20 18:14:52 (3.19 MB/s) - ‘NY_Hudson_South_20190919_TM_geo.pdf’ saved [54686460/54686460]
#
# --2022-11-20 18:14:53--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Lewbeach_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.246.59, 52.218.237.75, 52.92.160.57, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.246.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61624752 (59M) [application/pdf]
# Saving to: ‘NY_Lewbeach_20190919_TM_geo.pdf’
#
# NY_Lewbeach_2019091 100%[===================>]  58.77M  10.5MB/s    in 14s
#
# 2022-11-20 18:15:08 (4.08 MB/s) - ‘NY_Lewbeach_20190919_TM_geo.pdf’ saved [61624752/61624752]
#
# --2022-11-20 18:15:08--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Arena_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.160.129, 52.218.193.18, 52.218.229.147, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.160.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66242532 (63M) [application/pdf]
# Saving to: ‘NY_Arena_20190919_TM_geo.pdf’
#
# NY_Arena_20190919_T 100%[===================>]  63.17M  11.8MB/s    in 17s
#
# 2022-11-20 18:15:26 (3.74 MB/s) - ‘NY_Arena_20190919_TM_geo.pdf’ saved [66242532/66242532]
#
# --2022-11-20 18:15:26--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Seager_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.144.34, 52.218.234.179, 52.92.161.193, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.144.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71033425 (68M) [application/pdf]
# Saving to: ‘NY_Seager_20190919_TM_geo.pdf’
#
# NY_Seager_20190919_ 100%[===================>]  67.74M  12.4MB/s    in 17s
#
# 2022-11-20 18:15:44 (3.90 MB/s) - ‘NY_Seager_20190919_TM_geo.pdf’ saved [71033425/71033425]
#
# --2022-11-20 18:15:44--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Shandaken_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.197.10, 52.92.149.17, 52.218.236.91, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.197.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68390840 (65M) [application/pdf]
# Saving to: ‘NY_Shandaken_20190919_TM_geo.pdf’
#
# NY_Shandaken_201909 100%[===================>]  65.22M  12.1MB/s    in 17s
#
# 2022-11-20 18:16:02 (3.79 MB/s) - ‘NY_Shandaken_20190919_TM_geo.pdf’ saved [68390840/68390840]
#
# --2022-11-20 18:16:02--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Phoenicia_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.165.241, 52.92.145.177, 52.218.132.51, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.165.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 70104379 (67M) [application/pdf]
# Saving to: ‘NY_Phoenicia_20190919_TM_geo.pdf’
#
# NY_Phoenicia_201909 100%[===================>]  66.86M  14.5MB/s    in 6.1s
#
# 2022-11-20 18:16:09 (10.9 MB/s) - ‘NY_Phoenicia_20190919_TM_geo.pdf’ saved [70104379/70104379]
#
# --2022-11-20 18:16:09--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Bearsville_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.181.49, 52.92.179.185, 52.92.132.201, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.181.49|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68234591 (65M) [application/pdf]
# Saving to: ‘NY_Bearsville_20190919_TM_geo.pdf’
#
# NY_Bearsville_20190  41%[=======>            ]  27.07M  17.0KB/s    in 5m 56s
#
# 2022-11-20 18:22:07 (77.8 KB/s) - Connection closed at byte 28382539. Retrying.
#
# --2022-11-20 18:22:08--  (try: 2)  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Bearsville_20190919_TM_geo.pdf
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.181.49|:443... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 68234591 (65M), 39852052 (38M) remaining [application/pdf]
# Saving to: ‘NY_Bearsville_20190919_TM_geo.pdf’
#
# NY_Bearsville_20190 100%[++++++++===========>]  65.07M  2.94MB/s    in 23s
#
# 2022-11-20 18:22:32 (1.68 MB/s) - ‘NY_Bearsville_20190919_TM_geo.pdf’ saved [68234591/68234591]
#
# --2022-11-20 18:22:32--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Woodstock_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.149.129, 52.92.148.1, 52.218.229.227, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.149.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68881862 (66M) [application/pdf]
# Saving to: ‘NY_Woodstock_20190919_TM_geo.pdf’
#
# NY_Woodstock_201909 100%[===================>]  65.69M  6.76MB/s    in 22s
#
# 2022-11-20 18:22:54 (3.00 MB/s) - ‘NY_Woodstock_20190919_TM_geo.pdf’ saved [68881862/68881862]
#
# --2022-11-20 18:22:54--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Saugerties_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.165.249, 52.218.197.2, 52.218.252.52, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.165.249|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60297166 (58M) [application/pdf]
# Saving to: ‘NY_Saugerties_20190919_TM_geo.pdf’
#
# NY_Saugerties_20190 100%[===================>]  57.50M  4.17MB/s    in 26s
#
# 2022-11-20 18:23:22 (2.19 MB/s) - ‘NY_Saugerties_20190919_TM_geo.pdf’ saved [60297166/60297166]
#
# --2022-11-20 18:23:22--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Clermont_20190919_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.197.121, 52.218.168.211, 52.92.195.41, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.197.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 62404607 (60M) [application/pdf]
# Saving to: ‘NY_Clermont_20190919_TM_geo.pdf’
#
# NY_Clermont_2019091 100%[===================>]  59.51M  9.65MB/s    in 14s
#
# 2022-11-20 18:23:36 (4.31 MB/s) - ‘NY_Clermont_20190919_TM_geo.pdf’ saved [62404607/62404607]
#
# --2022-11-20 18:23:36--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Livingston_Manor_20190916_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.133.113, 52.218.168.211, 52.92.195.41, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.133.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60469320 (58M) [application/pdf]
# Saving to: ‘NY_Livingston_Manor_20190916_TM_geo.pdf’
#
# NY_Livingston_Manor 100%[===================>]  57.67M  11.0MB/s    in 17s
#
# 2022-11-20 18:23:54 (3.44 MB/s) - ‘NY_Livingston_Manor_20190916_TM_geo.pdf’ saved [60469320/60469320]
#
# --2022-11-20 18:23:54--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Willowemoc_20190916_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.179.105, 52.218.218.91, 52.218.168.19, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.179.105|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64466549 (61M) [application/pdf]
# Saving to: ‘NY_Willowemoc_20190916_TM_geo.pdf’
#
# NY_Willowemoc_20190 100%[===================>]  61.48M  17.6MB/s    in 4.2s
#
# 2022-11-20 18:23:59 (14.7 MB/s) - ‘NY_Willowemoc_20190916_TM_geo.pdf’ saved [64466549/64466549]
#
# --2022-11-20 18:23:59--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Claryville_20190916_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.213.155, 52.218.218.91, 52.218.168.19, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.213.155|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66670943 (64M) [application/pdf]
# Saving to: ‘NY_Claryville_20190916_TM_geo.pdf’
#
# NY_Claryville_20190 100%[===================>]  63.58M  11.9MB/s    in 17s
#
# 2022-11-20 18:24:17 (3.73 MB/s) - ‘NY_Claryville_20190916_TM_geo.pdf’ saved [66670943/66670943]
#
# --2022-11-20 18:24:17--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Peekamoose_Mountain_20190916_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.181.33, 52.218.168.251, 52.92.164.9, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.181.33|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66681169 (64M) [application/pdf]
# Saving to: ‘NY_Peekamoose_Mountain_20190916_TM_geo.pdf’
#
# NY_Peekamoose_Mount 100%[===================>]  63.59M  11.9MB/s    in 17s
#
# 2022-11-20 18:24:35 (3.76 MB/s) - ‘NY_Peekamoose_Mountain_20190916_TM_geo.pdf’ saved [66681169/66681169]
#
# --2022-11-20 18:24:35--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_West_Shokan_20190916_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.243.27, 52.218.253.11, 52.92.196.97, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.243.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65165640 (62M) [application/pdf]
# Saving to: ‘NY_West_Shokan_20190916_TM_geo.pdf’
#
# NY_West_Shokan_2019 100%[===================>]  62.15M  16.8MB/s    in 4.3s
#
# 2022-11-20 18:24:40 (14.3 MB/s) - ‘NY_West_Shokan_20190916_TM_geo.pdf’ saved [65165640/65165640]
#
# --2022-11-20 18:24:40--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Ashokan_20190916_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.192.161, 52.218.253.11, 52.92.196.97, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.192.161|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 60163703 (57M) [application/pdf]
# Saving to: ‘NY_Ashokan_20190916_TM_geo.pdf’
#
# NY_Ashokan_20190916 100%[===================>]  57.38M  7.24MB/s    in 18s
#
# 2022-11-20 18:25:00 (3.10 MB/s) - ‘NY_Ashokan_20190916_TM_geo.pdf’ saved [60163703/60163703]
#
# --2022-11-20 18:25:00--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Kingston_West_20190916_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.210.2, 52.218.160.26, 52.218.249.26, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.210.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64658808 (62M) [application/pdf]
# Saving to: ‘NY_Kingston_West_20190916_TM_geo.pdf’
#
# NY_Kingston_West_20 100%[===================>]  61.66M  11.4MB/s    in 6.1s
#
# 2022-11-20 18:25:07 (10.1 MB/s) - ‘NY_Kingston_West_20190916_TM_geo.pdf’ saved [64658808/64658808]
#
# --2022-11-20 18:25:07--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Kingston_East_20190930_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.147.105, 52.218.160.26, 52.218.249.26, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.147.105|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59834754 (57M) [application/pdf]
# Saving to: ‘NY_Kingston_East_20190930_TM_geo.pdf’
#
# NY_Kingston_East_20 100%[===================>]  57.06M  10.9MB/s    in 17s
#
# 2022-11-20 18:25:24 (3.46 MB/s) - ‘NY_Kingston_East_20190930_TM_geo.pdf’ saved [59834754/59834754]
#
# --2022-11-20 18:25:24--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Rock_City_20190930_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.133.57, 52.92.211.193, 52.92.192.185, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.133.57|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69511516 (66M) [application/pdf]
# Saving to: ‘NY_Rock_City_20190930_TM_geo.pdf’
#
# NY_Rock_City_201909 100%[===================>]  66.29M  15.1MB/s    in 9.5s
#
# 2022-11-20 18:25:34 (7.01 MB/s) - ‘NY_Rock_City_20190930_TM_geo.pdf’ saved [69511516/69511516]
#
# --2022-11-20 18:25:35--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Liberty_West_20190916_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.177.123, 52.92.211.193, 52.92.192.185, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.177.123|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 55393950 (53M) [application/pdf]
# Saving to: ‘NY_Liberty_West_20190916_TM_geo.pdf’
#
# NY_Liberty_West_201 100%[===================>]  52.83M  10.2MB/s    in 16s
#
# 2022-11-20 18:25:52 (3.22 MB/s) - ‘NY_Liberty_West_20190916_TM_geo.pdf’ saved [55393950/55393950]
#
# --2022-11-20 18:25:52--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Liberty_East_20190923_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.180.235, 52.218.251.19, 52.92.195.233, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.180.235|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56309713 (54M) [application/pdf]
# Saving to: ‘NY_Liberty_East_20190923_TM_geo.pdf’
#
# NY_Liberty_East_201 100%[===================>]  53.70M  10.4MB/s    in 16s
#
# 2022-11-20 18:26:09 (3.30 MB/s) - ‘NY_Liberty_East_20190923_TM_geo.pdf’ saved [56309713/56309713]
#
# --2022-11-20 18:26:09--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Grahamsville_20190916_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.216.170, 52.92.145.33, 52.218.193.26, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.216.170|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 57434188 (55M) [application/pdf]
# Saving to: ‘NY_Grahamsville_20190916_TM_geo.pdf’
#
# NY_Grahamsville_201 100%[===================>]  54.77M  10.4MB/s    in 16s
#
# 2022-11-20 18:26:26 (3.33 MB/s) - ‘NY_Grahamsville_20190916_TM_geo.pdf’ saved [57434188/57434188]
#
# --2022-11-20 18:26:27--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Rondout_Reservoir_20190916_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.233.211, 52.218.153.83, 52.218.183.1, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.233.211|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61904614 (59M) [application/pdf]
# Saving to: ‘NY_Rondout_Reservoir_20190916_TM_geo.pdf’
#
# NY_Rondout_Reservoi 100%[===================>]  59.04M  17.5MB/s    in 4.1s
#
# 2022-11-20 18:26:31 (14.6 MB/s) - ‘NY_Rondout_Reservoir_20190916_TM_geo.pdf’ saved [61904614/61904614]
#
# --2022-11-20 18:26:31--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Kerhonkson_20190916_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.222.11, 52.218.153.83, 52.218.183.1, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.222.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64820031 (62M) [application/pdf]
# Saving to: ‘NY_Kerhonkson_20190916_TM_geo.pdf’
#
# NY_Kerhonkson_20190 100%[===================>]  61.82M  11.4MB/s    in 17s
#
# 2022-11-20 18:26:49 (3.63 MB/s) - ‘NY_Kerhonkson_20190916_TM_geo.pdf’ saved [64820031/64820031]
#
# --2022-11-20 18:26:49--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Mohonk_Lake_20190916_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.218.11, 52.218.253.35, 52.92.165.233, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.218.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61641030 (59M) [application/pdf]
# Saving to: ‘NY_Mohonk_Lake_20190916_TM_geo.pdf.1’
#
# NY_Mohonk_Lake_2019 100%[===================>]  58.79M  11.0MB/s    in 17s
#
# 2022-11-20 18:27:07 (3.49 MB/s) - ‘NY_Mohonk_Lake_20190916_TM_geo.pdf.1’ saved [61641030/61641030]
#
# --2022-11-20 18:27:07--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Rosendale_20190923_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.216.34, 52.218.247.83, 52.218.160.94, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.216.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65716689 (63M) [application/pdf]
# Saving to: ‘NY_Rosendale_20190923_TM_geo.pdf’
#
# NY_Rosendale_201909 100%[===================>]  62.67M  11.8MB/s    in 17s
#
# 2022-11-20 18:27:25 (3.72 MB/s) - ‘NY_Rosendale_20190923_TM_geo.pdf’ saved [65716689/65716689]
#
# --2022-11-20 18:27:25--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Hyde_Park_20190927_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.218.133.97, 52.218.221.27, 52.92.212.209, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.218.133.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69539753 (66M) [application/pdf]
# Saving to: ‘NY_Hyde_Park_20190927_TM_geo.pdf’
#
# NY_Hyde_Park_201909 100%[===================>]  66.32M  12.4MB/s    in 17s
#
# 2022-11-20 18:27:43 (3.83 MB/s) - ‘NY_Hyde_Park_20190927_TM_geo.pdf’ saved [69539753/69539753]
#
# --2022-11-20 18:27:44--  https://prd-tnm.s3.amazonaws.com/StagedProducts/Maps/USTopo/PDF/NY/NY_Salt_Point_20190927_TM_geo.pdf
# Resolving prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)... 52.92.144.209, 52.218.222.43, 52.218.201.66, ...
# Connecting to prd-tnm.s3.amazonaws.com (prd-tnm.s3.amazonaws.com)|52.92.144.209|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71311426 (68M) [application/pdf]
# Saving to: ‘NY_Salt_Point_20190927_TM_geo.pdf’
#
# NY_Salt_Point_20190 100%[===================>]  68.01M  12.4MB/s    in 17s
#
# 2022-11-20 18:28:02 (3.90 MB/s) - ‘NY_Salt_Point_20190927_TM_geo.pdf’ saved [71311426/71311426]

# %%
# Coordinates of upper left corner, add -0.125N, 0.125W to get lower right
map_corners = [
    (42.375, -75.125, 'NY_Treadwell_20190925_TM_geo.pdf'),
    (42.375, -75.0, 'NY_Delhi_20190919_TM_geo.pdf'),
    (42.375, -74.875, 'NY_Bloomville_20190919_TM_geo.pdf'),
    (42.375, -74.75, 'NY_Hobart_20190919_TM_geo.pdf'),
    (42.375, -74.625, 'NY_Roxbury_20190919_TM_geo.pdf'),
    (42.375, -74.5, 'NY_Prattsville_20190919_TM_geo.pdf'),
    (42.375, -74.375, 'NY_Ashland_20190919_TM_geo.pdf'),
    (42.375, -74.25, 'NY_Hensonville_20190919_TM_geo.pdf'),
    (42.375, -74.125, 'NY_Freehold_20190919_TM_geo.pdf'),
    (42.375, -74.0, 'NY_Leeds_20190926_TM_geo.pdf'),
    (42.375, -73.875, 'NY_Hudson_North_20190919_TM_geo.pdf'),
    (42.375, -73.75, 'NY_Stottville_20190919_TM_geo.pdf'),
    (42.375, -73.625, 'NY_Chatham_20190919_TM_geo.pdf'),
    (42.375, -73.5, 'MA_State_Line_20210415_TM_geo.pdf'),

    (42.25, -75.125, 'NY_Walton_East_20190925_TM_geo.pdf'),
    (42.25, -75.0, 'NY_Hamden_20160818_TM_geo.pdf'),
    (42.25, -74.875, 'NY_Andes_20190919_TM_geo.pdf'),
    (42.25, -74.75, 'NY_Margaretville_20190919_TM_geo.pdf'),
    (42.25, -74.625, 'NY_Fleischmanns_20190925_TM_geo.pdf'),
    (42.25, -74.5, 'NY_West_Kill_20190919_TM_geo.pdf'),
    (42.25, -74.375, 'NY_Lexington_20190919_TM_geo.pdf'),
    (42.25, -74.25, 'NY_Hunter_20190919_TM_geo.pdf'),
    (42.25, -74.125, 'NY_Kaaterskill_Clove_20190919_TM_geo.pdf'),
    (42.25, -74.0, 'NY_Cementon_20190919_TM_geo.pdf'),
    (42.25, -73.875, 'NY_Hudson_South_20190919_TM_geo.pdf'),
    (42.25, -73.75, 'NY_Claverack_20190919_TM_geo.pdf'),
    (42.25, -73.625, 'NY_Hillsdale_20190926_TM_geo.pdf'),
    (42.25, -73.5, 'MA_Egremont_20210415_TM_geo.pdf'),
    
    (42.125, -75.125, 'NY_Corbett_20190925_TM_geo.pdf'),
    (42.125, -75.0, 'NY_Downsville_20190919_TM_geo.pdf'),
    (42.125, -74.875, 'NY_Lewbeach_20190919_TM_geo.pdf'),
    (42.125, -74.75, 'NY_Arena_20190919_TM_geo.pdf'),
    (42.125, -74.625, 'NY_Seager_20190919_TM_geo.pdf'),
    (42.125, -74.5, 'NY_Shandaken_20190919_TM_geo.pdf'),
    (42.125, -74.375, 'NY_Phoenicia_20190919_TM_geo.pdf'),
    (42.125, -74.25, 'NY_Bearsville_20190919_TM_geo.pdf'),
    (42.125, -74.125, 'NY_Woodstock_20190919_TM_geo.pdf'),
    (42.125, -74.0, 'NY_Saugerties_20190919_TM_geo.pdf'),
    (42.125, -73.875, 'NY_Clermont_20190919_TM_geo.pdf'),
    (42.125, -73.75, 'NY_Ancram_20190919_TM_geo.pdf'),
    (42.125, -73.625, 'NY_Copake_20190919_TM_geo.pdf'),
    (42.125, -73.5, 'MA_Bash_Bish_Falls_20210415_TM_geo.pdf'),


    (42.0, -75.125, 'NY_Horton_20190916_TM_geo.pdf'),
    (42.0, -75.0, 'NY_Roscoe_20190916_TM_geo.pdf'),
    (42.0, -74.875, 'NY_Livingston_Manor_20190916_TM_geo.pdf'),
    (42.0, -74.75, 'NY_Willowemoc_20190916_TM_geo.pdf'),
    (42.0, -74.625, 'NY_Claryville_20190916_TM_geo.pdf'),
    (42.0, -74.5, 'NY_Peekamoose_Mountain_20190916_TM_geo.pdf'),
    (42.0, -74.375, 'NY_West_Shokan_20190916_TM_geo.pdf'),
    (42.0, -74.25, 'NY_Ashokan_20190916_TM_geo.pdf'),
    (42.0, -74.125, 'NY_Kingston_West_20190916_TM_geo.pdf'),
    (42.0, -74.0, 'NY_Kingston_East_20190930_TM_geo.pdf'),
    (42.0, -73.875, 'NY_Rock_City_20190930_TM_geo.pdf'),
    (42.0, -73.75, 'NY_Pine_Plains_20190927_TM_geo.pdf'),
    (42.0, -73.625, 'NY_Millerton_20190927_TM_geo.pdf'),
    (42.0, -73.5, 'CT_Sharon_20210227_TM_geo.pdf'),

    (41.875, -75.125, 'NY_Callicoon_20190920_TM_geo.pdf'),
    (41.875, -75.0, 'NY_Jeffersonville_20190923_TM_geo.pdf'),
    (41.875, -74.875, 'NY_Liberty_West_20190916_TM_geo.pdf'),
    (41.875, -74.75, 'NY_Liberty_East_20190923_TM_geo.pdf'),
    (41.875, -74.625, 'NY_Grahamsville_20190916_TM_geo.pdf'),
    (41.875, -74.5, 'NY_Rondout_Reservoir_20190916_TM_geo.pdf'),
    (41.875, -74.375, 'NY_Kerhonkson_20190916_TM_geo.pdf'),
    (41.875, -74.25, 'NY_Mohonk_Lake_20190916_TM_geo.pdf'),
    (41.875, -74.125, 'NY_Rosendale_20190923_TM_geo.pdf'),
    (41.875, -74.0, 'NY_Hyde_Park_20190927_TM_geo.pdf'),
    (41.875, -73.875, 'NY_Salt_Point_20190927_TM_geo.pdf'),
    (41.875, -73.75, 'NY_Millbrook_20190926_TM_geo.pdf'),
    (41.875, -73.625, 'NY_Amenia_20190926_TM_geo.pdf'),
    (41.875, -73.5, 'CT_Ellsworth_20210305_TM_geo.pdf'),
]

# %%
def get_corners_from_gdal_ds(gdal_ds):
    ulx, xres, _, lry, _, yres = gdal_ds.GetGeoTransform()
    uly = orig_pdf.RasterYSize * yres + lry
    lrx = orig_pdf.RasterXSize * xres + ulx
    return ulx, uly, lrx, lry

# Get approx aspect ratio - just pick random one from the middle
fn = map_corners[len(map_corners)//2][-1]
orig_pdf = gdal.Open(fn)
ulx, uly, lrx, lry = get_corners_from_gdal_ds(orig_pdf)
ASPECT_RATIO = (ulx - lrx) / (uly - lry)

def warp_pdf(map_info):
    uly, ulx, quadrangle = map_info
    orig_pdf = gdal.Open(quadrangle)
    target_size = 4096 # equidistant
    warped = gdal.Warp(
        'warped.tif', orig_pdf, 
        dstSRS='EPSG:4326', # WGS84 
        resampleAlg='cubic',
        width=target_size, height=target_size,
        # this takes min_x, min_y, max_x, max_y
        outputBounds=(ulx, uly - 0.125, ulx + 0.125, uly)
    );
    warped.FlushCache();
    return warped

def gdal_ds_to_image(gdal_ds):
    a1 = gdal_ds.GetRasterBand(1).ReadAsArray()
    a2 = gdal_ds.GetRasterBand(2).ReadAsArray()
    a3 = gdal_ds.GetRasterBand(3).ReadAsArray()

    arr = np.stack((a1, a2, a3), axis=2)
    return Image.fromarray(arr)

def correct_aspect_ratio(im):
    return im.resize(
        (int(im.width * ASPECT_RATIO), im.height), Image.Resampling.BICUBIC
    )

def make_name_readable(fn):
    return fn.split('_20')[0][3:]
    

def do_all_the_things(map_info):
    im = correct_aspect_ratio(gdal_ds_to_image(warp_pdf(map_info)))
    im.save(f'{make_name_readable(map_info[-1])}.tif')
    return im

# %%
def merge_files(map_corners, crop_pixels=(0, 0, 0, 0)):
    
    row_lats = list(set(m[0] for m in map_corners))
    row_lats.sort()
    column_lons = list(set(m[1] for m in map_corners))
    column_lons.sort()

    # n.b. all input files have been transformed to the same size
    for ir, row in enumerate(row_lats):
        print(row)
        maps = [m for m in map_corners if m[0] == row]
        print(', '.join(make_name_readable(m[-1]) for m in maps))

        for ic, col in enumerate(column_lons):
            m = [m for m in maps if m[1] == col][0][-1]
            if ic == 0:
                im = Image.open(f'{make_name_readable(m)}.tif')
                im = crop_image(im, crop_pixels)
                continue 
            im_new = Image.open(f'{make_name_readable(m)}.tif')
            im_new = crop_image(im_new, crop_pixels)
            im = merge_im_horizontally(im, im_new)
        
        if ir == 0:
            im_all = im
            continue
        im_all = merge_im_vertically(im_all, im)

    return im_all

def crop_image(im, n_pixels):
    box = (n_pixels[0], n_pixels[1], im.width - n_pixels[2], im.height - n_pixels[3])
    return im.crop(box)
            
def merge_im_horizontally(im1, im2):
    w = im1.width + im2.width 
    h = im1.height
    im = Image.new("RGB", (w, h))
    im.paste(im1)
    im.paste(im2, (im1.width, 0))
    return im

def merge_im_vertically(im1, im2):
    w = im1.width
    h = im1.height + im2.height 
    im = Image.new("RGB", (w, h))
    im.paste(im2)
    im.paste(im1, (0, im2.height))
    return im

def increase_contrast(im, contrast_scale=3):
    enhancer = ImageEnhance.Contrast(im)
    return enhancer.enhance(contrast_scale)

# %%
for m in map_corners:
    if len(glob.glob(f'{make_name_readable(m[-1])}.tif')) == 0: # skip files that have already been processed
        print(make_name_readable(m[-1]))
        im = do_all_the_things(m)


im = merge_files(map_corners, (2, 1, 1, 2))
im.save('test.tif')
im3 = increase_contrast(im, 1.5)
sc = 1.5
im2 = im3.resize((int(im.width / sc), int(im.height / sc)), Image.Resampling.BICUBIC)
im2.save('final_map.tif')
# Out:
# Treadwell
# Delhi
# State_Line
# Walton_East
# Hamden
# Egremont
# Corbett
# Downsville
# Bash_Bish_Falls
# Horton
# Roscoe
# Sharon
# Callicoon
# Jeffersonville
# Ellsworth
# 41.875
# Callicoon, Jeffersonville, Liberty_West, Liberty_East, Grahamsville, Rondout_Reservoir, Kerhonkson, Mohonk_Lake, Rosendale, Hyde_Park, Salt_Point, Millbrook, Amenia, Ellsworth
# 42.0
# Horton, Roscoe, Livingston_Manor, Willowemoc, Claryville, Peekamoose_Mountain, West_Shokan, Ashokan, Kingston_West, Kingston_East, Rock_City, Pine_Plains, Millerton, Sharon
# 42.125
# Corbett, Downsville, Lewbeach, Arena, Seager, Shandaken, Phoenicia, Bearsville, Woodstock, Saugerties, Clermont, Ancram, Copake, Bash_Bish_Falls
# 42.25
# Walton_East, Hamden, Andes, Margaretville, Fleischmanns, West_Kill, Lexington, Hunter, Kaaterskill_Clove, Cementon, Hudson_South, Claverack, Hillsdale, Egremont
# 42.375
# Treadwell, Delhi, Bloomville, Hobart, Roxbury, Prattsville, Ashland, Hensonville, Freehold, Leeds, Hudson_North, Stottville, Chatham, State_Line
